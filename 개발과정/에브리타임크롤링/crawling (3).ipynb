# %%
# from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

# 브라우저 꺼짐 방지 옵션
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
chrome_driver = "C:\\Users\\wjdfo\\OneDrive\\바탕 화면\\chromedriver-win64\\chromedriver.exe"

driver = webdriver.Chrome(chrome_driver, options=chrome_options)
driver.get('https://everytime.kr/login')

# %%
#x_path 찾는 법 : html 코드 위에 우클릭 -> copy -> x_path 누르면 copy 됨
professor = ['김정근', '권영우', '남우정', '김승호', '아난드 폴',
             '정기숙', '임경식', '정원일', '정선미', '이호경', '배준현',
             '이상윤', '박소은', '김용태', '백호기', '남덕윤', '이우진', '김경훈',
             '장재석', '이시형', '김진욱', '김재수', '김필영', '김명석', '백낙훈',
             '박상효', '펑리메이', '김재일', '김명옥', '정창수', '이용주', '정설영',
             '이종택', '서영균', '이성희', '김동선', '김령환', '김동균', '김구진']

for name in professor:
    url = 'https://everytime.kr/lecture/search?keyword='+name+'&condition=professor'

    driver.get(url)
    time.sleep(3)

    #교수명 검색 후 강의들 반환
    lectures = driver.find_elements(By.CLASS_NAME, "lecture")
    for lecture in lectures :
        lecture.click()
        time.sleep(3)

        #강의명 교수명 출력
        info = driver.find_elements(By.CLASS_NAME, "info")
        print(info[0].text)
        print(info[1].text)

        #강의평 평점 출력
        try : 
            rate = driver.find_element(By.CLASS_NAME, "rating")
        except :
            driver.back()
            print("강의평 없음")
            continue
        print(rate.text)

        #강의평
        driver.find_element(By.CLASS_NAME, "more").click()
        time.sleep(3)
        articles = driver.find_elements(By.CLASS_NAME, "article")
        for article in articles :
            print(article.text)
        driver.back()
        time.sleep(3)

        driver.back()
        time.sleep(3)
# Out:
# 과목명
# 차세대 컴퓨팅 시스템
# 교수명
# 김명석,남덕윤,김정근
# 강의평 없음
#
# 과목명
# 컴파일러
# 교수명
# 김정근
# 5
# 37%
# 4
# 40%
# 3
# 17%
# 2
# 3%
# 1
# 3%
#
# 23년 1학기 수강자
# 추천
# 신고
# 교수님이 과목에 대해서 정말 잘 아시고 설명도 자세히 해주신다. 수업 질문도 잘 받아주고 과제도 추가 설명까지 해줄정도로 편의를 많이 봐주신다. 과제를 계속 연장하셨는데 연장 전에 낸 사람은 가산점을 따줘서 기준도 명확한 교수님이다. 다만...약속을 정말 안 지키신다 중간고사 성적은 그냥 성적 나올때 본다고 생각하는게 좋다. ~를 올려주겠다 하면 그냥 편하게 일주일 더 걸리겠구나 생각하는게 낫다...
# 23년 1학기 수강자
# 추천
# 신고
# 교수님 열정적이시고 강의 전달력도 좋으셨음, 시험은 피피티 암기하고 연습많이 하면 잘 볼 것 같고 과제는 이번에 처음 내주셨는데 향후 계속 우려먹을 과제를 내신 것 같아서 나중에 족보를 타지 않을까 하는 걱정이 듦
# 23년 1학기 수강자
# 추천
# 신고
# 아직 신임 교수님이다보니 수업 진행 방식, 다소 난잡한 공지에 약속 지키는 것에 있어서 아쉬움이 있었고 중간 이후 과제 하는게 너무 힘들어서 포기할까 고민도 했지만 그래도 온라인으로 질문하면 늦은 시간에도 하나하나씩 다 답변해주시고 학생들 배려해서 과제 제출 기간 연장해주시고 성적도 너그럽게 주셨습니다 교수님 연륜이 조금 더 쌓이면 충분히 좋은 강의가 될 것 같아요
# 23년 1학기 수강자
# 추천
# 신고
# 교수님은 좋은데.. 뭔가.. 뭔가 아쉬움.. 시간 약속 잘 지키시면 5점인데..
# 23년 1학기 수강자
# 추천
# 신고
# 재미있게 들었습니다. 교수님이 되게 열정적이시고 잘 가르치시긴 한데 강의시간에 복습으로 빠지는 시간이 너무 깁니다. 과제는 어려운 건 아닌데 양 자체가 많다보니 시간을 많이 써야 하고, 시험 기간에 겹쳐서 내는 경우가 많습니다.
# 23년 1학기 수강자
# 추천
# 신고
# 교수님 설명 잘 해주셔서 너무 좋아요. 최대한 낙오자 없게 하려고 친절하게 끝까지 설명해주신다고 느꼈어요. 그런데 자바 컴파일이나 cpp 컴파일 같은 부수적인 걸 오히려 더 많이 설명해주시고 본 수업의 parse tree 같은 건 되게 가볍게 넘어간 것 같아요. 과제는 깃헙에 잘 찾아보면 다른 사람이 짜둔 코드가 있어서 좀 아쉬웠어요. 근데 깃헙의 코드가 몇몇 케이스에서 안 돌아가기도 해서 오히려 좋은 것 같기도 하네요. 그래도 컴파일러를 스캐너부터 만들어 볼 수 있어서 매우 유익했다고 생각합니다. 프로그래밍 언어가 어떻게 동작하는지 알게되면서 코딩 능력도 더 올라간 것 같아요. 수업 들은 거 후회하지 않습니다. 그런데 교수님 왠만한 것들에 대해서 시간을 잘 안 시키시긴 해요. 시험 전에 요약 영상 올려주신 건 좋았어요.
# 23년 1학기 수강자
# 추천
# 신고
# 오토마타 들으면서 같이 들었는데 나쁘지 않았음
# 과제도 어렵다곤 하는데 막상 해보면 진짜 헛웃음나올정도로 쉬움
# 대부분 로직은 교수님이 제공해주고 거기에 맞춰서 노가다마냥 끼워맞추는 방식이라 어렵다기보다는 귀찮다에 가깝다고 생각함
# 물론 절대적인 양은 한번에 쏟아져서 많다고 생각함
# 시험도 사전에 예제 문제 템플릿 제공해주고 풀이까지 해줘서 수업 대충 듣다가 전날에 벼락치기로 해도 충분히 좋은 점수 받을 수 있었음
# 강의력 자체는 그렇게 좋은 편은 아니었음 수업마다 똑같은 말 계속 하다가 본론으로 들어가는 타임이 너무 늦어져서 그런듯
# 23년 1학기 수강자
# 추천
# 신고
# 수업을 잘 따라가시면 남는게 많은 수업인듯 합니다.
# 실습과제 4개가 좀 많이 힘든 편입니다.
# 23년 1학기 수강자
# 추천
# 신고
# 쉽지 않다
# 교수님은 굉장히 열정적이시고 과제 설명으로 1시간도 쓰실정도로 상세하게 강의하심
# 문제는 그럼에도 불구하고 양이 너무 많고 교수님 말도 빠르심. 과제도 원래 3까지 생각하신거 2까지만 했는데 전공수업 처음으로 중간에 포기했음. 얻어가는게 없진 않은데 들을거면 오토마타는 듣고 오는게 나을듯
# 23년 1학기 수강자
# 추천
# 신고
# 컴파일러가 어떻게 돌아가는지 알긴 알게 됨.
# 오토마타 안듣고 이 과목 들어도 별 상관 없다곤 하지만
# 오토마타 안듣고 이 과목 들은 주변 친구들 보면 어려워함.
# 물론 오토마타 듣고 이 과목 들어도 어려움 ㅋㅋㅋ
#
# 장점 : ㅋ
# 단점 :
# 1. 무조건 풀강 or 5분 오버
# 2. 말 개빠름 ㄹㅇ
# 3. 같은 말 무한 반복. 강의 녹음 했더니 pdf하나에 260분
# 4. 자료 중구난방해서 공부할때 뭘 해야할지 햇갈림
# 5. 과제 쉽지 않다고 웃으면서 말하는데 개킹받음
# 5. 시간 안지킴. 주말 성적 오늘, 다음주, 이러더니 기말 끝나고도 안올림. 근데 과제 주의사항 공지는 수십개 바로올림
# 23년 1학기 수강자
# 추천
# 신고
# 강의는 말이 조금 빠른편입니다
# 교수님이 매우 열정적이셔서 많은것들을 배울수있습니다
# 23년 1학기 수강자
# 추천
# 신고
# 뭐랄까 뭐 컴파일러가 뭔지 배울수 있어서 좋았으나 사실 쉽진 않다 과제도 과제고 시험도 그렇고 근데 교수님이 슬랙으로 피드백 잘줘서 좋다 물어보면 다대답해주심
# 23년 1학기 수강자
# 추천
# 신고
# 교수님이 열정적이십니다. 그러나 과목이 어려운지ㅇ해하기는 힘들었습니다. 과제하면서 많이 깨달았습니다.
# 23년 1학기 수강자
# 추천
# 신고
# 열심히 준비하시고 수업도 열심히하십니다 추천해요
# 23년 1학기 수강자
# 추천
# 신고
# 어렵지만 교수님께서 친절하게 설명을 잘 해 주십니다. 다만 아쉬운점은 약속을 잘 지키지 않으시다는 점.
# 23년 1학기 수강자
# 6
# 추천
# 신고
# 개인적으로 너무 별로였던 수업.
# 장점: 교수님께서 친절하심. 강의자료 퀄리티 좋음(다 직접제작은 아닌듯). 질문을 많이 하면 얻는게 많음. 설명이 자세함.
#
# 단점: 강의력이 안좋음. 1분이면 전달할 수 있는 내용을 10분에 걸쳐서 설명하심. 오히려 다음 수업의 복습 시간에 정리해주는게 이해가 빠름.
# (개인적 의견이지만 목소리 데시벨도 75분동안 항상 크고, 말과 말 사이에 쉼이 없어서 집중하기에 힘듦)
# 강의자료가 줄줄이 올라오는데 뭐가 뭔지 파악하기 힘듦.
# 일정 잘 안지키심
# 시험 빡셈
# 과제 어렵고 많음(이론 수업이 아닌 것 같은 기분)
#
# 요약: 교수님은 착하시고 학생 배려 많이 해주시지만 보통의 학생들에게는 너무 빡센 수업
# 23년 1학기 수강자
# 추천
# 신고
# 교수님 열정 넘치시고 수업 잘해주시고 이것저것 학생들 위해서 신경 많이 써주십니다. 다만 말하기속도가 1.2배속 정도신데 수업 따라가기 힘들 수 있어요. 가끔 강의녹화 올려주시는데 자세하고 길게 올려주셔서 저는 녹화본으로 이해했네요 인강 짱..
# 컴파일러 과목 자체가 어려워요. 과제는 아마 수업 따라갈 수 있으시면 그렇게 어렵진 않을겁니다. Java나 c++ 하실 수 있으면 과제하기 좋아요.
#
# 교수님이 좋으시고 과목이 어려웠다
# 23년 1학기 수강자
# 추천
# 신고
# 듣기 좋은 강의에요!
# 지금까지 막히는 부분없이 왔네요.
# 마지막까지 학생들을 위해 열심히 강의하십니다!
# 23년 1학기 수강자
# 2
# 추천
# 신고
# 열정 넘치시고 질문도 잘 받아주시고 다 좋습니다.
# 다만 초반에 진도 달릴때 좀 어지럽고 수업도 헤비하고 과제도 빡셉니다.
# 그래도 열심히 알려주셔서 노력하면 할만은 합니다.
# 23년 1학기 수강자
# 1
# 추천
# 신고
# 강의는 진짜 뭔가 얻어간다는 느낌을 받긴 받았는데 교수님이 바쁘신지 일정에 대한 약속을 지킨적이 없음. 딱히 불편함을 느끼진 않았는데 그냥 그랬다고
#
# 과목명
# 컴퓨터구조
# 교수명
# 김정근
# 5
# 35%
# 4
# 30%
# 3
# 20%
# 2
# 10%
# 1
# 5%
#
# 23년 2학기 수강자
# 추천
# 신고
# 교수님이 어느정도 열정이 넘치시고 말을 또박또박 잘 하시는 것 같습니다 그냥저냥 듣기 무난해요
# 22년 2학기 수강자
# 추천
# 신고
# 영어수업이라 학점 받기는 좋은거 같아요. 나머진 그닥
# 22년 2학기 수강자
# 추천
# 신고
# 시험 문제 안내 및 과제 설명을 엄청 잘해주시고 은근 꼼꼼하게가르쳐주심
# 22년 2학기 수강자
# 추천
# 신고
# 영어라 알아듣기 힘든 부분이 있기는 했지만 강의의 내용이나 시험전에 한글로 정리해주실때 분야에 대해서 정말 잘 알고계시는게 느껴졌습니다 강의자료로 잘 제공해주셔서 많이 질문하시거나 혼자 독학하시는 분들이 들으면 좋을것같아요
# 22년 2학기 수강자
# 추천
# 신고
# 영어 수업이라 힘들지만 성적을 후하게 주십니다
# 22년 2학기 수강자
# 추천
# 신고
# 정말 후하게 점수 주셔서 모든 게 다 괜찮아지는 마법. 학기가 끝나서 미화됐을 수도 있지만 ^^
# 22년 2학기 수강자
# 추천
# 신고
# 과목 자체도 어려운데 영어 수업이라 더 어려움. 대신 교수님이 엄청 친절하심. 시험 전에 한국어 요약 강의도 올려주시고, 시험 예시 문제도 주시고 과제도 최대한 많은 정보를 알려주심. 뭐라도 열심히 한 티를 내면 알아주시는듯..!
# 22년 2학기 수강자
# 추천
# 신고
# 두번째 과제 같은경우 시험 2주전에 내주셨지만 강의진도가 밀려 결국 시험끝나고 남은 이틀간해야됨...
# 22년 2학기 수강자
# 추천
# 신고
# 영어 수업인데도 시험 임박할 때 쯤 한국어 정리 영상도 올려주셔서 좋았습니다.
# 다른 컴구 강의 자료랑 비교해봤을 때 강의 자료가 아주 깔끔한게 혼자 공부할 때 도움 많이 됐습니다.
# 교수님의 영어는 다른 강의평에서 적은대로
# 영어 수업 아니면 이 교수님 수업 괜찮을듯
# 22년 2학기 수강자
# 추천
# 신고
# 수업은 조금 횡설수설 하시지만 교수님은 정말 착하고 친절하셔요. 기본적으로 성적 후하게 잘 주시는 것도 있고, 열심히 하면 그만큼 성적 잘 나오는 수업인 것 같습니다!
# 22년 2학기 수강자
# 추천
# 신고
# 영어 강의인 거 꼭 알고 신청하세요... 교수님께서 열심히 하시는 것 같은데 과목 자체가 어렵고 설명이 명확하지 않아서 따라가기 힘들었어요
# 22년 2학기 수강자
# 추천
# 신고
# 영어수업으로 하는게 아니라면 깔끔한듯
# 영어로 말하면 전달하려는 바를 재대로 전달 못하심
# 학생 생각은 나름 해주시는 느낌이 듬
# 22년 2학기 수강자
# 추천
# 신고
# 총평 생각보다 낮은거 보고 아쉬워서 막학기지만 강의평 씁니다
# 과제도 타 교수님에 비해 무난하고 적당했고 내용도 수강 전에 독학할때 이게 무슨 🐕소린지.. 싶었던거 잘 알려주시고 (원래 컴퓨터구조는 어려운과목이니까요...) 멍청한 질문해도 잘 알려주셔서 좋았습니다!
# 근데 보강을 세번 하셔서 좀 눈물날뻔했어요
# 쪽지시험도 치시긴 하는데 이건 어렵지 않아요
# 과제 지각제출 받아주시고 너그러우신편입니당
# 22년 2학기 수강자
# 추천
# 신고
# 교수님은 친절하지만 수업 내용이 어려워요ㅠㅠㅠ
# 22년 2학기 수강자
# 추천
# 신고
# 친절 하시긴합니다.
# 근데 진도 너무 느려서 시험기간에 보강을 3번이나 하시는건 좀..
# 수업시간도 기본 5분 오버하십니다.
# 교수밈은 착하셔요
# 22년 2학기 수강자
# 추천
# 신고
# 영어로 수업하는데 뭐라하는지 모르겠음;;
#
# 시험전에 보강같은거는 lms에 한국말로 강의해주던데 그거 보면 강의는 나름 잘 하시는거 같은데
# 제발 영어로 수업은 안해주셨으면 좋겠다
# 22년 2학기 수강자
# 추천
# 신고
# 진도를 너무 천천히 나가시는 것 빼고는 무난했습니다
# 22년 2학기 수강자
# 추천
# 신고
# 안그래도 어려운 과목인데 영어로 들으니까 뭔가 더 애매하네요 교수님의 영어 실력이 그렇게 막 뛰어나신 것 같지는 않구요 근데 엄청 친절하세요
# 22년 2학기 수강자
# 추천
# 신고
# 교수님께서 영어를 애매하게 하심 그래서 잘 못 알아듣겠음 (미국 교환학생 간 적 있는데 거기서는 전공 잘 알아들은거 보면 내 영어문제는 아니라고 생각)
# 22년 2학기 수강자
# 2
# 추천
# 신고
# 영어 강의였어요
# 제가 영어를 못하고 공부도 안해서 이해가 안되기는 한데요.......성적도 아마 안좋겠지만 교수님은 진짜 친절하고 좋아요.
# 과제도 있는데 할만해요.
#
# 다만 시간약속이 잘 안지켜져서 별 한개 뺐어요
# 중간고사때 진도 덜나간거 당일날 밤까지 영상으로 올려준다 하셨는데 좀 늦었고 한국어로 된 써머리도 중간고사 전까지 올려주겠다고 하셨는데 다 안올라왔어요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 42
#      40     print(article.text)
#      41 driver.back()
# ---> 42 time.sleep(3)
#      44 driver.back()
#      45 time.sleep(3)
#
# KeyboardInterrupt:
